# %% [markdown]
# <a href="https://colab.research.google.com/github/tckccai/AAI614_ElChemaly/blob/main/PythonFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AAI614 Participation Activity

print("Hello from my Python file")
# Out:
# Hello from my Python file
